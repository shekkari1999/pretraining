# %%
## lets get the data from huggingface

from datasets import load_dataset

## here you can add how many workers can help you load data from huggingface
data = load_dataset('wikitext', 'wikitext-103-v1')

# %%
## explore data
print(type(data))
print(data)


print(data['train'])
# Out:
# <class 'datasets.dataset_dict.DatasetDict'>
# DatasetDict({
#     test: Dataset({
#         features: ['text'],
#         num_rows: 4358
#     })
#     train: Dataset({
#         features: ['text'],
#         num_rows: 1801350
#     })
#     validation: Dataset({
#         features: ['text'],
#         num_rows: 3760
#     })
# })
# Dataset({
#     features: ['text'],
#     num_rows: 1801350
# })

# %%
## this is how you access 
print(data['train'][5]['text'])
# Out:
#  It met with positive sales in Japan , and was praised by both Japanese and western critics . After release , it received downloadable content , along with an expanded edition in November of that year . It was also adapted into manga and an original video animation series . Due to low sales of Valkyria Chronicles II , Valkyria Chronicles III was not localized , but a fan translation compatible with the game 's expanded edition was released in 2014 . Media.Vision would return to the franchise with the development of Valkyria : Azure Revolution for the PlayStation 4 .

# %%
## lets encode
import tiktoken
enc = tiktoken.get_encoding('gpt2')
## can we encode the above example ???
enc.encode(data['train'][5]['text'])
# Out:
# [632,
#  1138,
#  351,
#  3967,
#  4200,
#  287,
#  2869,
#  837,
#  290,
#  373,
#  15342,
#  416,
#  1111,
#  4960,
#  290,
#  8830,
#  9188,
#  764,
#  2293,
#  2650,
#  837,
#  340,
#  2722,
#  41496,
#  2695,
#  837,
#  1863,
#  351,
#  281,
#  9902,
#  8313,
#  287,
#  3389,
#  286,
#  326,
#  614,
#  764,
#  632,
#  373,
#  635,
#  16573,
#  656,
#  15911,
#  290,
#  281,
#  2656,
#  2008,
#  11034,
#  2168,
#  764,
#  14444,
#  284,
#  1877,
#  4200,
#  286,
#  569,
#  18354,
#  7496,
#  17740,
#  2873,
#  837,
#  569,
#  18354,
#  7496,
#  17740,
#  6711,
#  373,
#  407,
#  36618,
#  837,
#  475,
#  257,
#  4336,
#  11059,
#  11670,
#  351,
#  262,
#  983,
#  705,
#  82,
#  9902,
#  8313,
#  373,
#  2716,
#  287,
#  1946,
#  764,
#  6343,
#  13,
#  44206,
#  561,
#  1441,
#  284,
#  262,
#  8663,
#  351,
#  262,
#  2478,
#  286,
#  569,
#  18354,
#  7496,
#  1058,
#  22134,
#  9303,
#  329,
#  262,
#  14047,
#  604,
#  764,
#  220,
#  198]

# %%
## we have to add the eot token as per our requirement here
